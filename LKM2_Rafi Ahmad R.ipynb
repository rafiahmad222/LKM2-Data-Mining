# %% [markdown]
# <a href="https://colab.research.google.com/github/rafiahmad222/LKM2-Data-Mining/blob/main/LKM2_Rafi%20Ahmad%20R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-14fb233f-1456-46c4-a4a2-c117d1ce8d06" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-14fb233f-1456-46c4-a4a2-c117d1ce8d06">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data =pd.read_csv('iris_dataset.csv')

# %%
setosa = np.array(data[data['Species_name'] == 'Setosa'].values[:, 1:])
print("Setosa:")
print(setosa)
# Out:
# Setosa:
# [[0.2 1.4 3.5 5.1 'Setosa']
#  [0.2 1.4 3.0 4.9 'Setosa']
#  [0.2 1.3 3.2 4.7 'Setosa']
#  [0.2 1.5 3.1 4.6 'Setosa']
#  [0.2 1.4 3.6 5.0 'Setosa']
#  [0.4 1.7 3.9 5.4 'Setosa']
#  [0.3 1.4 3.4 4.6 'Setosa']
#  [0.2 1.5 3.4 5.0 'Setosa']
#  [0.2 1.4 2.9 4.4 'Setosa']
#  [0.1 1.5 3.1 4.9 'Setosa']
#  [0.2 1.5 3.7 5.4 'Setosa']
#  [0.2 1.6 3.4 4.8 'Setosa']
#  [0.1 1.4 3.0 4.8 'Setosa']
#  [0.1 1.1 3.0 4.3 'Setosa']
#  [0.2 1.2 4.0 5.8 'Setosa']
#  [0.4 1.5 4.4 5.7 'Setosa']
#  [0.4 1.3 3.9 5.4 'Setosa']
#  [0.3 1.4 3.5 5.1 'Setosa']
#  [0.3 1.7 3.8 5.7 'Setosa']
#  [0.3 1.5 3.8 5.1 'Setosa']
#  [0.2 1.7 3.4 5.4 'Setosa']
#  [0.4 1.5 3.7 5.1 'Setosa']
#  [0.2 1.0 3.6 4.6 'Setosa']
#  [0.5 1.7 3.3 5.1 'Setosa']
#  [0.2 1.9 3.4 4.8 'Setosa']
#  [0.2 1.6 3.0 5.0 'Setosa']
#  [0.4 1.6 3.4 5.0 'Setosa']
#  [0.2 1.5 3.5 5.2 'Setosa']
#  [0.2 1.4 3.4 5.2 'Setosa']
#  [0.2 1.6 3.2 4.7 'Setosa']
#  [0.2 1.6 3.1 4.8 'Setosa']
#  [0.4 1.5 3.4 5.4 'Setosa']
#  [0.1 1.5 4.1 5.2 'Setosa']
# ...

# %%
versicolor = np.array(data[data['Species_name'] == 'Versicolor'].values[:, 1:])
print("\nVersicolor:")
print(versicolor)
# Out:
# Versicolor:
# [[1.4 4.7 3.2 7.0 'Versicolor']
#  [1.5 4.5 3.2 6.4 'Versicolor']
#  [1.5 4.9 3.1 6.9 'Versicolor']
#  [1.3 4.0 2.3 5.5 'Versicolor']
#  [1.5 4.6 2.8 6.5 'Versicolor']
#  [1.3 4.5 2.8 5.7 'Versicolor']
#  [1.6 4.7 3.3 6.3 'Versicolor']
#  [1.0 3.3 2.4 4.9 'Versicolor']
#  [1.3 4.6 2.9 6.6 'Versicolor']
#  [1.4 3.9 2.7 5.2 'Versicolor']
#  [1.0 3.5 2.0 5.0 'Versicolor']
#  [1.5 4.2 3.0 5.9 'Versicolor']
#  [1.0 4.0 2.2 6.0 'Versicolor']
#  [1.4 4.7 2.9 6.1 'Versicolor']
#  [1.3 3.6 2.9 5.6 'Versicolor']
#  [1.4 4.4 3.1 6.7 'Versicolor']
#  [1.5 4.5 3.0 5.6 'Versicolor']
#  [1.0 4.1 2.7 5.8 'Versicolor']
#  [1.5 4.5 2.2 6.2 'Versicolor']
#  [1.1 3.9 2.5 5.6 'Versicolor']
#  [1.8 4.8 3.2 5.9 'Versicolor']
#  [1.3 4.0 2.8 6.1 'Versicolor']
#  [1.5 4.9 2.5 6.3 'Versicolor']
#  [1.2 4.7 2.8 6.1 'Versicolor']
#  [1.3 4.3 2.9 6.4 'Versicolor']
#  [1.4 4.4 3.0 6.6 'Versicolor']
#  [1.4 4.8 2.8 6.8 'Versicolor']
#  [1.7 5.0 3.0 6.7 'Versicolor']
#  [1.5 4.5 2.9 6.0 'Versicolor']
# ...

# %%
verginica = np.array(data[data['Species_name'] == 'Verginica'].values[:, 1:])
print("\nVerginica:")
print(verginica)
# Out:
# Verginica:
# [[2.5 6.0 3.3 6.3 'Verginica']
#  [1.9 5.1 2.7 5.8 'Verginica']
#  [2.1 5.9 3.0 7.1 'Verginica']
#  [1.8 5.6 2.9 6.3 'Verginica']
#  [2.2 5.8 3.0 6.5 'Verginica']
#  [2.1 6.6 3.0 7.6 'Verginica']
#  [1.7 4.5 2.5 4.9 'Verginica']
#  [1.8 6.3 2.9 7.3 'Verginica']
#  [1.8 5.8 2.5 6.7 'Verginica']
#  [2.5 6.1 3.6 7.2 'Verginica']
#  [2.0 5.1 3.2 6.5 'Verginica']
#  [1.9 5.3 2.7 6.4 'Verginica']
#  [2.1 5.5 3.0 6.8 'Verginica']
#  [2.0 5.0 2.5 5.7 'Verginica']
#  [2.4 5.1 2.8 5.8 'Verginica']
#  [2.3 5.3 3.2 6.4 'Verginica']
#  [1.8 5.5 3.0 6.5 'Verginica']
#  [2.2 6.7 3.8 7.7 'Verginica']
#  [2.3 6.9 2.6 7.7 'Verginica']
#  [1.5 5.0 2.2 6.0 'Verginica']
#  [2.3 5.7 3.2 6.9 'Verginica']
#  [2.0 4.9 2.8 5.6 'Verginica']
#  [2.0 6.7 2.8 7.7 'Verginica']
#  [1.8 4.9 2.7 6.3 'Verginica']
#  [2.1 5.7 3.3 6.7 'Verginica']
#  [1.8 6.0 3.2 7.2 'Verginica']
#  [1.8 4.8 2.8 6.2 'Verginica']
#  [1.8 4.9 3.0 6.1 'Verginica']
#  [2.1 5.6 2.8 6.4 'Verginica']
# ...

# %%
unknown = np.array(data[data['Species_name'] == 'unknown'].values[:, 1:])
print("\nUnknown:")
print(unknown[: ])
# Out:
# Unknown:
# [[0.3 1.4 3.0 4.8 'unknown']
#  [0.2 1.6 3.8 5.1 'unknown']
#  [0.2 1.4 3.2 4.6 'unknown']
#  [0.2 1.5 3.7 5.3 'unknown']
#  [0.2 1.4 3.3 5.0 'unknown']
#  [1.2 4.2 3.0 5.7 'unknown']
#  [1.3 4.2 2.9 5.7 'unknown']
#  [1.3 4.3 2.9 6.2 'unknown']
#  [1.1 3.0 2.5 5.1 'unknown']
#  [1.3 4.1 2.8 5.7 'unknown']
#  [2.3 5.2 3.0 6.7 'unknown']
#  [1.9 5.0 2.5 6.3 'unknown']
#  [2.0 5.2 3.0 6.5 'unknown']
#  [2.3 5.4 3.4 6.2 'unknown']
#  [1.8 5.1 3.0 5.9 'unknown']]

# %%
# a. Sepal length dan petal width
setosa_sepal_length = setosa[:, 0]
setosa_petal_width = setosa[:, 3]
plt.scatter(setosa_sepal_length, setosa_petal_width, color="red", label="setosa")

versicolor_sepal_length = versicolor[:, 0]
versicolor_petal_width = versicolor[:, 3]
plt.scatter(versicolor_sepal_length, versicolor_petal_width, color="green", label="versicolor")

verginica_sepal_length = verginica[:, 0]
verginica_petal_width = verginica[:, 3]
plt.scatter(verginica_sepal_length, verginica_petal_width, color="blue", label="verginica")

unknown_sepal_length = unknown[:, 0]
unknown_petal_width = unknown[:, 3]
plt.scatter(unknown_sepal_length, unknown_petal_width, color="yellow", label="unknown")

plt.title('Sepal Length dan Petal Width')
plt.xlabel('Sepal Length')
plt.ylabel('Petal Width')
plt.legend(fontsize='small')
plt.show()

# %%
# b. Sepal width dan petal length
setosa_sepal_width = setosa[:, 1]
setosa_petal_length = setosa[:, 2]
plt.scatter(setosa_sepal_width, setosa_petal_length, color="red", label="setosa")

versicolor_sepal_width = versicolor[:, 1]
versicolor_petal_length = versicolor[:, 2]
plt.scatter(versicolor_sepal_width, versicolor_petal_length, color="green", label="versicolor")

verginica_sepal_width = verginica[:, 1]
verginica_petal_length = verginica[:, 2]
plt.scatter(verginica_sepal_width, verginica_petal_length, color="blue", label="verginica")

unknown_sepal_width = unknown[:, 1]
unknown_petal_length = unknown[:, 2]
plt.scatter(unknown_sepal_width, unknown_petal_length, color="yellow", label="unknown")

plt.title('Sepal Width dan Petal Length')
plt.xlabel('Sepal Width')
plt.ylabel('Petal Length')
plt.legend(fontsize='small')
plt.show()

# %%
# c. Sepal length dan petal length

setosa_sepal_length = setosa[:, 0]
setosa_petal_length = setosa[:, 2]
plt.scatter(setosa_sepal_length, setosa_petal_length, color="red", label="setosa")

versicolor_sepal_length = versicolor[:, 0]
versicolor_petal_length = versicolor[:, 2]
plt.scatter(versicolor_sepal_length, versicolor_petal_length, color="green", label="versicolor")

verginica_sepal_length = verginica[:, 0]
verginica_petal_length = verginica[:, 2]
plt.scatter(verginica_sepal_length, verginica_petal_length, color="blue", label="verginica")

unknown_sepal_length = unknown[:, 0]
unknown_petal_length = unknown[:, 2]
plt.scatter(unknown_sepal_length, unknown_petal_length, color="yellow", label="unknown")

plt.title('Sepal Length dan Petal Length')
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.legend(fontsize='small')
plt.show()

# %%
# d. Sepal width dan petal width

setosa_sepal_width = setosa[:, 1]
setosa_petal_width = setosa[:, 3]
plt.scatter(setosa_sepal_width, setosa_petal_width, color="red", label="setosa")

versicolor_sepal_width = versicolor[:, 1]
versicolor_petal_width = versicolor[:, 3]
plt.scatter(versicolor_sepal_width, versicolor_petal_width, color="green", label="versicolor")

verginica_sepal_width = verginica[:, 1]
verginica_petal_width = verginica[:, 3]
plt.scatter(verginica_sepal_width, verginica_petal_width, color="blue", label="verginica")

unknown_sepal_width = unknown[:, 1]
unknown_petal_width = unknown[:, 3]
plt.scatter(unknown_sepal_width, unknown_petal_width, color="yellow", label="unknown")

plt.title('Sepal Width dan Petal Width')
plt.xlabel('Sepal Width')
plt.ylabel('Petal Width')
plt.legend(fontsize='small')
plt.show()

# %%
# Memilih data berkelas Setosa, Versicolor, dan Virginica
species_data = {
    'Setosa': data[data['Species_name'] == 'Setosa'],
    'Versicolor': data[data['Species_name'] == 'Versicolor'],
    'Virginica': data[data['Species_name'] == 'Verginica']
}

colors = {'Setosa': 'red', 'Versicolor': 'green', 'Virginica': 'blue'}

for species, color in colors.items():
    for _, row in species_data[species].iterrows():
        plt.plot(range(1, 5), row[['Petal_width', 'Petal_length', 'Sepal_width', 'Sepal_length']],
                 color=color, alpha=0.5, label=species if _ == 0 else "")
plt.xticks(range(1, 5), ['Petal Width', 'Petal Length', 'Sepal Width', 'Sepal Length'])
plt.xlabel('Features')
plt.ylabel('Length (cm)')
plt.title('Paralel Coordinat Plot')
plt.grid(True)
plt.show()
